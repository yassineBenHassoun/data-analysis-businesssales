# %%
import pandas as pd
import numpy as np
from os import getcwd
from datetime import datetime

# %%
pwd
# Out:
# '/lab/sales/data_processing'

# %%
transactions = pd.read_csv("../data_values_origin/transactions.csv")

# %%
testList = transactions[transactions['date'].str.contains('test', na=True) == True]

# %%
## moins 200 ligne 
transactionWithoutTest = transactions[transactions['date'].str.contains('test', na=True) == False]
transactionWithoutTest
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 337011   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [336816 rows x 4 columns]

# %%
transactionWithoutTest['date'] = pd.to_datetime(transactionWithoutTest['date'], errors='coerce')
transactionWithoutTest
# Out:
# <ipython-input-7-b1e2f6af6aa9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactionWithoutTest['date'] = pd.to_datetime(transactionWithoutTest['date'], errors='coerce')
#        id_prod                       date session_id client_id
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226 2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374 2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                        ...        ...       ...
# 337011   1_671 2021-05-28 12:35:46.214839    s_40720    c_3454
# ...

# %%
transactionWithoutTest['transaction_date'] = pd.DatetimeIndex(transactionWithoutTest['date']).date
transactionWithoutTest
# Out:
# <ipython-input-8-8ba57fa608a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactionWithoutTest['transaction_date'] = pd.DatetimeIndex(transactionWithoutTest['date']).date
#        id_prod                       date session_id client_id  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226 2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374 2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                        ...        ...       ...
# 337011   1_671 2021-05-28 12:35:46.214839    s_40720    c_3454
# ...

# %%
transactionWithoutTest['year'] = pd.DatetimeIndex(transactionWithoutTest['date']).year
transactionWithoutTest['month'] = pd.DatetimeIndex(transactionWithoutTest['date']).month

transactionWithoutTest.dtypes
# Out:
# <ipython-input-9-814fa63851a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactionWithoutTest['year'] = pd.DatetimeIndex(transactionWithoutTest['date']).year
# <ipython-input-9-814fa63851a8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactionWithoutTest['month'] = pd.DatetimeIndex(transactionWithoutTest['date']).month
# id_prod                     object
# date                datetime64[ns]
# session_id                  object
# client_id                   object
# ...

# %%
transactionWithoutTest
# Out:
#        id_prod                       date session_id client_id  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226 2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374 2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                        ...        ...       ...
# 337011   1_671 2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759 2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256 2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227 2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417 2021-06-26 14:38:19.732946    s_54117    c_6714
#
#        transaction_date  year  month
# 0            2021-04-10  2021      4
# 1            2022-02-03  2022      2
# 2            2021-09-23  2021      9
# 3            2021-10-17  2021     10
# ...

# %%
showNa = transactionWithoutTest.columns[transactionWithoutTest.isnull().any()]

showNa
# Out:
# Index([], dtype='object')

# %%
## nous avons pas de na  transactionWithoutTest

transactionWithoutTest
# Out:
#        id_prod                       date session_id client_id  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226 2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374 2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                        ...        ...       ...
# 337011   1_671 2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759 2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256 2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227 2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417 2021-06-26 14:38:19.732946    s_54117    c_6714
#
#        transaction_date  year  month
# 0            2021-04-10  2021      4
# 1            2022-02-03  2022      2
# 2            2021-09-23  2021      9
# 3            2021-10-17  2021     10
# ...

# %%
duplicateProduct = transactionWithoutTest[transactionWithoutTest.duplicated(['client_id','session_id'])]
duplicateProduct
## on comprend que un client à bien acheter plusieurs produits
# Out:
#        id_prod                       date session_id client_id  \
# 563     0_1334 2021-12-20 19:54:33.947616   s_137385    c_1318
# 852      1_706 2021-04-13 09:11:54.849801    s_19950    c_1367
# 919     0_1446 2021-09-09 21:10:59.869217    s_87456    c_2917
# 1422    0_1097 2021-11-12 05:45:06.609257   s_118374    c_2438
# 1427    0_2162 2021-04-08 09:57:34.294741    s_17661    c_4525
# ...        ...                        ...        ...       ...
# 337008   1_413 2022-01-10 13:47:23.973957   s_147795    c_3706
# 337009  0_1475 2021-07-22 13:47:39.400914    s_65686    c_5607
# 337010   1_498 2022-02-03 01:39:15.793010   s_159138    c_1857
# 337012   0_759 2021-06-19 00:19:23.917703    s_50568    c_6268
# 337015  0_1417 2021-06-26 14:38:19.732946    s_54117    c_6714
#
#        transaction_date  year  month
# 563          2021-12-20  2021     12
# 852          2021-04-13  2021      4
# 919          2021-09-09  2021      9
# 1422         2021-11-12  2021     11
# ...

# %%
transactionWithoutTest
# Out:
#        id_prod                       date session_id client_id  \
# 0       0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226 2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374 2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                        ...        ...       ...
# 337011   1_671 2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012   0_759 2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013  0_1256 2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014   2_227 2021-10-30 16:50:15.997750   s_112349       c_5
# 337015  0_1417 2021-06-26 14:38:19.732946    s_54117    c_6714
#
#        transaction_date  year  month
# 0            2021-04-10  2021      4
# 1            2022-02-03  2022      2
# 2            2021-09-23  2021      9
# 3            2021-10-17  2021     10
# ...

# %%
transactionWithoutTest = transactionWithoutTest.rename(columns={"id_prod":"id_product", "date":"sell_date", "year":"sell_year"})
transactionWithoutTest
# Out:
#        id_product                  sell_date session_id client_id  \
# 0          0_1483 2021-04-10 18:37:28.723910    s_18746    c_4450
# 1           2_226 2022-02-03 01:55:53.276402   s_159142     c_277
# 2           1_374 2021-09-23 15:13:46.938559    s_94290    c_4270
# 3          0_2186 2021-10-17 03:27:18.783634   s_105936    c_4597
# 4          0_1351 2021-07-17 20:34:25.800563    s_63642    c_1242
# ...           ...                        ...        ...       ...
# 337011      1_671 2021-05-28 12:35:46.214839    s_40720    c_3454
# 337012      0_759 2021-06-19 00:19:23.917703    s_50568    c_6268
# 337013     0_1256 2021-03-16 17:31:59.442007     s_7219    c_4137
# 337014      2_227 2021-10-30 16:50:15.997750   s_112349       c_5
# 337015     0_1417 2021-06-26 14:38:19.732946    s_54117    c_6714
#
#        transaction_date  sell_year  month
# 0            2021-04-10       2021      4
# 1            2022-02-03       2022      2
# 2            2021-09-23       2021      9
# ...

# %%
transactionWithoutTest.to_csv("../sales/data-clear/transactions.csv", index = False, header=True)
